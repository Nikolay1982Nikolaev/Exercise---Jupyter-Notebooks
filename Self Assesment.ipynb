# %% [markdown]
# ## Project name: Nobel Prize Data Exploration
# ## Project author: Nikolay Nikolaev
#
# ### Terms and conditions:
# * Use Jupyter notebook for text and maths. You can use any programming language you would like.
# * Write your research and code in English. Bulgarian is also acceptable but try to use English.
# * If you have sensitive, copyrighted, or copy-protected assets, including but not limited to, images, multimedia, code, documents, and datasets,
#   you can sign an NDA (non-disclosure agreement) with the SoftUni team. Contact the lecturer if you need assistance with the process.
# * Any code which does not comply with the Bulgarian law (as of the exam date), will be given zero points.
# * Any malicious code, or code intended to do harm to the user's computer, information, or privacy, will be given zero points.
#
# By submitting your project for the exam, you agree with these terms and conditions.
#
# ### Self-assessment:
# The numbers in brackets define possible points for the corresponding item.
# Replace the numbers in brackets with your own estimation.
# ** Example: **
# 1. Problem statement: 7
# 2. Problem description: 3
# (end of example)
#
# 1. Problem statement (0-10)
# 	* How well is the problem defined? Not very well, I was so confused
# 	* Does the research address a real-life problem? Isn't real life problem, but the argument was interesting for me
# 	* Does the research solve the correct problem? - No. I can't find similar articul.
#     * Total: 7
# 2. Layout (0-20)
# 	* Are the document sections structured properly? - Yes. I main part are well structured: code, documantation, ecplanation-9
# 	* Is the article well-formatted (in terms of readability)? Yes. I belive this time, I was beter than during the Math COurse - 7
#     * Total: 16
# 3. Code quality (0-20)
# 	* Is the code well-written? Is the code self-documenting? Yes. I strongli belive
# 	* Is the code organized into functions?   Not exactly, I havant so many functional code
# 	* Is the code generally well-structured? - Yes. Generally is well-structured.
#     * total: 15
# 4. Previous research (0-10)
# 	* Have you cited at least two other sources? Yes. I have citation from multiple sors.
# 	* Does the project contain comparisons between the current and the previous results? I'm not sure.
#     * Total: 7
# 5. Gathering / generating, cleaning, and formatting data (0-10)
# 	* Every problem deals with "real-world" data in some way. Even if you don't use datasets, you'll likely generate some data.
# 	* How is the data gathered? Yes.I belive
# 	* Is the process statistically valid? Yes.I belive.
# 	* Is the process of data acquisition, data cleaning, and data manipulation well documented? Yes. I belive.
#     * Total: 7
# 6. Testing (0-10)
# 	* This can have various meanings: unit testing, hypothesis testing, train/test data set, etc. Yes. I did Che0squared Test
# 	* Is the code thoroughly tested? Yes
# 	* Are there any comparisons to other implementations / other articles / previous research?
#     Total: 7
# 7. Visualization (0-10)
# 	* All kinds of projects employ some visualization: graphical plots, tables, etc.
# 	* Are all visualizations correct (i.e. convey the intended meaning without misleading the intended audience)?
# 	* Are all visualizations clear, and easy to understand?
#     * Total: 7
# 8. Communication (0-10)
# 	* Does the project tell the story correctly?
# 	* Does the project serve the audience it was intended for?
#     * Total: 7
#
# Grand Total: 70
